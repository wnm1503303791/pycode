# %%
# %matplotlib inline

# %% [markdown]
# 1. Getting Started with FCN Pre-trained Models
# ==============================================
#
# This is a quick demo of using GluonCV FCN model on PASCAL VOC dataset.
# Please follow the `installation guide <../index.html>`_ to install MXNet and GluonCV if not yet.

# %%
import mxnet as mx
from mxnet import image
from mxnet.gluon.data.vision import transforms
import gluoncv
# using cpu
ctx = mx.cpu(0)

# %% [markdown]
# Prepare the image
# -----------------
#
# download the example image

# %%
#url = 'https://raw.githubusercontent.com/dmlc/web-data/master/gluoncv/segmentation/voc_examples/1.jpg'
filename = 'data/1/example.jpg'
#gluoncv.utils.download(url, filename)

# %% [markdown]
# load the image

# %%
img = image.imread(filename)

from matplotlib import pyplot as plt
plt.imshow(img.asnumpy())
plt.show()

# %% [markdown]
# normalize the image using dataset mean

# %%
from gluoncv.data.transforms.presets.segmentation import test_transform
img = test_transform(img, ctx)

# %% [markdown]
# Load the pre-trained model and make prediction
# ----------------------------------------------
#
# get pre-trained model

# %%
model = gluoncv.model_zoo.get_model('fcn_resnet101_voc', pretrained=True)

# %% [markdown]
# make prediction using single scale

# %%
output = model.predict(img)
predict = mx.nd.squeeze(mx.nd.argmax(output, 1)).asnumpy()

# %% [markdown]
# Add color pallete for visualization

# %%
from gluoncv.utils.viz import get_color_pallete
import matplotlib.image as mpimg
mask = get_color_pallete(predict, 'pascal_voc')
mask.save('data/1/output.png')

# %% [markdown]
# show the predicted mask

# %%
mmask = mpimg.imread('data/1/output.png')
plt.imshow(mmask)
plt.show()

# %% [markdown]
# More Examples
#  -------------

# %%
filename = 'data/2/1.jpg'
img = image.imread(filename)

plt.imshow(img.asnumpy())
plt.show()

img = test_transform(img, ctx)

output = model.predict(img)
predict = mx.nd.squeeze(mx.nd.argmax(output, 1)).asnumpy()

mask = get_color_pallete(predict, 'pascal_voc')
mask.save('data/2/output1.png')

mmask = mpimg.imread('data/2/output1.png')
plt.imshow(mmask)
plt.show()

# %%
filename = 'data/2/2.jpg'
img = image.imread(filename)

plt.imshow(img.asnumpy())
plt.show()

img = test_transform(img, ctx)

output = model.predict(img)
predict = mx.nd.squeeze(mx.nd.argmax(output, 1)).asnumpy()

mask = get_color_pallete(predict, 'pascal_voc')
mask.save('data/2/output2.png')

mmask = mpimg.imread('data/2/output2.png')
plt.imshow(mmask)
plt.show()

# %%
filename = 'data/2/3.jpg'
img = image.imread(filename)

plt.imshow(img.asnumpy())
plt.show()

img = test_transform(img, ctx)

output = model.predict(img)
predict = mx.nd.squeeze(mx.nd.argmax(output, 1)).asnumpy()

mask = get_color_pallete(predict, 'pascal_voc')
mask.save('data/2/output3.png')

mmask = mpimg.imread('data/2/output3.png')
plt.imshow(mmask)
plt.show()
